# %%
import numpy as np

# Dữ liệu ví dụ cho 7 ngày
data = np.array([
    [30, 70, 5],  
    [32, 65, 0],   
    [28, 80, 10],  
    [27, 75, 0],   
    [31, 60, 2],   
    [29, 85, 20],  
    [33, 55, 0],   
])
#dữ liệu từng cột 
temperature = data[:, 0]   
humidity    = data[:, 1]   
rainfall    = data[:, 2]   
#các giá trị thống kê
avg_temp = temperature.mean()
max_rain = rainfall.max()
min_hum  = humidity.min()
#ngày có lượng mưa cao nhất
day_max_rain = np.argmax(rainfall) + 1 
#lọc ra những ngày mưa trên 5mm
rainy_days = data[data[:, 2] > 5]
#thêm một cột "chỉ số nóng bức"
heat_index = (data[:,0] * data[:,1] / 100).reshape(-1,1)
new_data = np.hstack([data, heat_index])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import numpy as np
#       3 # Dữ liệu ví dụ cho 7 ngày
#       4 data = np.array([
#       5     [30, 70, 5],
#       6     [32, 65, 0],
#    (...)     11     [33, 55, 0],
#      12 ])
#
# ModuleNotFoundError: No module named 'numpy'
