# %%
data = np.array([
    [30, 70, 5],
    [32, 65, 0],
    [28, 80, 10],
    [27, 75, 0],
    [31, 60, 2],
    [29, 85, 20],
    [33, 55, 0],
])
#slicing
three_days = data[:3] #lấy 3 ngày đầu
two_cols = data[:, :2] #lấy 2 cột đầu
#indexing
hum_day4 = data[3, 1] #lấy độ ẩm của ngày thứ 4
day5 = data[4] #lấy toàn bộ hàng ngày 5
#boolean mask
hot_days = data[data[:,0] > 30] #lọc ngày nhiệt độ trên 30 độ c
rainy = data[data[:,2] > 0] # lọc ngày trời mưa
cond = (data[:,0] > 28) & (data[:,1] > 70) #lọc ngày nhiệt độ lớn hơn 28 và độ ẩm lớn hơn 70
result = data[cond]
#fancy indexing 
selected = data[[0,2,5]] #lấy dữ liệu của ngày 1,3,6
temp_rain = data[:, [0,2]] #lấy các cột 0 và 2
#broadcasting
new_temp = data[:,0] + 2 #thêm 2 độ c vào toàn bộ cột nhiệt độ
new_humidity = data[:,1] - 5 #giảm độ ẩm xuống 5% cho mọi ngày
score = data[:,0]*2 + data[:,1] - data[:,2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = np.array([
#       2     [30, 70, 5],
#       3     [32, 65, 0],
#       4     [28, 80, 10],
#       5     [27, 75, 0],
#       6     [31, 60, 2],
#       7     [29, 85, 20],
#       8     [33, 55, 0],
#       9 ])
#      10 #slicing
#      11 three_days = data[:3] #lấy 3 ngày đầu
#
# NameError: name 'np' is not defined
