# %%
import numpy as np
data = np.array([
    [30, 70, 5],
    [32, 65, 0],
    [29, 80, 10],
    [35, 60, 0],
    [28, 85, 25],
    [27, 90, 30],
    [31, 75, 2]
])
#nhiệt độ trung bình 
temp_mean = np.mean(data[:, 0])
#tìm ngày có độ ẩm cao nhất 
max_humidity = np.max(data[:, 1])
day_max_humid = np.argmax(data[:, 1])
#tổng lượng mưa trong tuần 
total_rain = np.sum(data[:, 2])
#tìm các ngày không mưa 
no_rain_days = data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 data = np.array([
#       3     [30, 70, 5],
#       4     [32, 65, 0],
#    (...)      9     [31, 75, 2]
#      10 ])
#
# ModuleNotFoundError: No module named 'numpy'
